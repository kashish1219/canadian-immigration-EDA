# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("canadian_immigration_data1980-2024.csv")

# %%
data.columns
# Out:
# Index(['Country', 'ISO Code', 'Continent', 'Region', 'DevName', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021', '2022', '2023', '2024', 'Total',
#        'July - 2024'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 1980           1981           1982          1983  \
# count     189.000000     189.000000     189.000000    189.000000
# mean     1281.857143    1265.492063    1192.677249    871.465608
# std     10560.072806    9565.444213    8973.876106   6570.439245
# min         0.000000       0.000000       0.000000      0.000000
# 25%         0.000000       0.000000       1.000000      0.000000
# 50%        15.000000      16.000000      14.000000     16.000000
# 75%       272.000000     301.000000     299.000000    201.000000
# max    143135.000000  128618.000000  121147.000000  89157.000000
#
#                1984          1985          1986           1987           1988  \
# count    189.000000    189.000000    189.000000     189.000000     189.000000
# mean     855.259259    816.291005    980.915344    1517.804233    1593.825397
# std     6504.523340   6202.262560   7300.075903   11217.055446   11983.770620
# ...

# %%
data.head(5)
# Out:
#        Country ISO Code Continent              Region             DevName  \
# 0        Total      TOT     World                 NaN                 NaN
# 1        India      IND      Asia       Southern Asia  Developing regions
# 2  Philippines      PHL      Asia  South-Eastern Asia  Developing regions
# 3        China      CHN      Asia        Eastern Asia  Developing regions
# 4      Nigeria      NGA    Africa      Western Africa  Developing regions
#
#        1980      1981      1982     1983     1984  ...    2017    2018  \
# 0  143135.0  128618.0  121147.0  89157.0  88239.0  ...  286535  321055
# 1    8880.0    8670.0    8147.0   7338.0   5704.0  ...   51590   69985
# 2    6051.0    5921.0    5249.0   4562.0   3801.0  ...   40905   35050
# 3    5123.0    6682.0    3308.0   1863.0   1527.0  ...   30250   29710
# 4      81.0      60.0      58.0     58.0     78.0  ...    5445   10920
#
#      2019    2020    2021    2022    2023    2024     Total  July - 2024
# ...

# %%
data = data.iloc[:,:-1]

# %%
total = data.iloc[0]
total = total['1980':'2023']

# %%
total.isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(16,8))
sns.lineplot(x=total.index, y=total.values, marker='o', label='data', color='black')
plt.xlabel('Years')
plt.xticks(rotation=45)
plt.ylabel('Immigration')
plt.legend()
plt.grid(True)
plt.show()

# %%
ruling_party = {'1980':'Liberals','1981':'Liberals','1982':'Liberals','1983':'Liberals',
                 '1984':'Conservative','1985':'Conservative','1986':'Conservative','1987':'Conservative',
                 '1988':'Conservative','1989':'Conservative','1990':'Conservative','1991':'Conservative',
                 '1992':'Conservative','1993':'Liberals','1994':'Liberals','1995':'Liberals',
                 '1996':'Liberals','1997':'Liberals','1998':'Liberals','1999':'Liberals',
                 '2000':'Liberals','2001':'Liberals','2002':'Liberals','2003':'Liberals',
                 '2000':'Liberals','2001':'Liberals','2002':'Liberals','2003':'Liberals',
                 '2004':'Liberals','2005':'Liberals','2006':'Conservative','2007':'Conservative',
                 '2008':'Conservative','2009':'Conservative','2010':'Conservative','2011':'Conservative',
                 '2012':'Conservative','2013':'Conservative','2014':'Conservative','2015':'Liberals',
                 '2016':'Liberals','2017':'Liberals','2018':'Liberals','2019':'Liberals',
                 '2020':'Liberals','2021':'Liberals','2022':'Liberals','2023':'Liberals'}

# %%
politics_in_canada = pd.DataFrame(
    {
        'imm_total':total,
        'Ruling_Party':pd.Series(ruling_party)
    }
)
politics_in_canada
# Out:
#      imm_total  Ruling_Party
# 1980  143135.0      Liberals
# 1981  128618.0      Liberals
# 1982  121147.0      Liberals
# 1983   89157.0      Liberals
# 1984   88239.0  Conservative
# 1985   84302.0  Conservative
# 1986   99354.0  Conservative
# 1987  152098.0  Conservative
# 1988  161929.0  Conservative
# 1989  192001.0  Conservative
# 1990  214230.0  Conservative
# 1991  232800.0  Conservative
# 1992  254800.0  Conservative
# 1993  256600.0      Liberals
# 1994  224400.0      Liberals
# 1995  212864.0      Liberals
# 1996  226071.0      Liberals
# 1997  216014.0      Liberals
# 1998  174159.0      Liberals
# 1999  189922.0      Liberals
# 2000  227429.0      Liberals
# 2001  250640.0      Liberals
# 2002  229048.0      Liberals
# 2003  221349.0      Liberals
# 2004  235824.0      Liberals
# 2005  262241.0      Liberals
# 2006  251649.0  Conservative
# 2007  236762.0  Conservative
# 2008  247261.0  Conservative
# 2009  252218.0  Conservative
# 2010  280730.0  Conservative
# ...

# %%
custom = {'Liberals': 'red','Conservative':'blue'}
plt.figure(figsize=(16,8))
ax1 = sns.scatterplot(
                x=politics_in_canada.index,
                y=politics_in_canada['imm_total'], 
                hue=politics_in_canada.Ruling_Party,
                palette=custom,
                s=100)
plt.xlabel('Years')
plt.ylabel('Immigration')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
hs = pd.read_csv('houses.csv')
hs.head(5)
# Out:
#           Unnamed: 0        Geography   Canada Unnamed: 3 Unnamed: 4  \
# 0  Housing estimates     Type of unit     1980       1981       1982
# 1     Housing starts              NaN    Units        NaN        NaN
# 2                NaN      Total units  158,601    177,973    125,860
# 3                NaN  Single-detached   87,721     89,071     54,457
# 4                NaN        Multiples   70,880     88,902     71,403
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 37  \
# 0       1983       1984       1985       1986       1987  ...        2015
# 1        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 2    162,645    134,900    165,826    199,785    245,986  ...     195,535
# 3    102,385     83,651     98,624    120,008    140,139  ...      68,125
# 4     60,260     51,249     67,202     79,777    105,847  ...     127,410
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43  \
# ...

# %%
hs = hs.set_index('Unnamed: 0')
hs = hs.loc[['Housing estimates','Housing completions']]

# %%
hs
# Out:
#                         Geography   Canada Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# Unnamed: 0
# Housing estimates    Type of unit     1980       1981       1982       1983
# Housing completions   Total units  176,168    174,996    133,942    163,008
#
#                     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# Unnamed: 0
# Housing estimates         1984       1985       1986       1987        1988
# Housing completions    153,012    139,106    184,605    217,976     216,532
#
#                      ... Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40  \
# Unnamed: 0           ...
# Housing estimates    ...        2015        2016        2017        2018
# Housing completions  ...     194,461     187,605     190,923     200,262
#
#                     Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# Unnamed: 0
# Housing estimates          2019        2020        2021        2022
# Housing completions     187,177     198,761     222,670     219,942
#
# ...

# %%
hs.columns = hs.iloc[0]
hs = hs.drop('Housing estimates', axis=0)

# %%
hs = hs.iloc[:, :-2]

# %%
hs = hs.loc['Housing completions'].reset_index()
hs = hs.iloc[1:]
hs = hs.set_index('Housing estimates')
hs['Housing completions'] = hs['Housing completions'].replace({',': ''}, regex=True).astype(int)

# %%
plt.figure(figsize=(16, 8))

ax1 = sns.scatterplot(
                x=politics_in_canada.index,
                y=politics_in_canada['imm_total'], 
                hue=politics_in_canada.Ruling_Party,
                palette=custom,
                s=100)
plt.plot(hs.index, hs['Housing completions'], color='green', linewidth=2.5, label='Houses Built')
plt.legend()
plt.xlabel('Years')
plt.ylabel('Immigration')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
politics_in_canada=politics_in_canada[:-1]
df = politics_in_canada.join(hs)
df
# Out:
#      imm_total  Ruling_Party  Housing completions
# 1980  143135.0      Liberals               176168
# 1981  128618.0      Liberals               174996
# 1982  121147.0      Liberals               133942
# 1983   89157.0      Liberals               163008
# 1984   88239.0  Conservative               153012
# 1985   84302.0  Conservative               139106
# 1986   99354.0  Conservative               184605
# 1987  152098.0  Conservative               217976
# 1988  161929.0  Conservative               216532
# 1989  192001.0  Conservative               217371
# 1990  214230.0  Conservative               206163
# 1991  232800.0  Conservative               160014
# 1992  254800.0  Conservative               173245
# 1993  256600.0      Liberals               161794
# 1994  224400.0      Liberals               162085
# 1995  212864.0      Liberals               119501
# 1996  226071.0      Liberals               117834
# 1997  216014.0      Liberals               143386
# ...

# %%
party_stats = df.groupby('Ruling_Party')[['imm_total', 'Housing completions']].mean().round(2)
party_stats['imm_per_house'] = (party_stats['imm_total']/party_stats['Housing completions'])
party_stats
# Out:
#                   imm_total  Housing completions imm_per_house
# Ruling_Party
# Conservative  209679.722222            188496.17      1.112382
# Liberals           238155.2            173559.36      1.372183

# %% [markdown]
# On average, during Liberal governments, about 1.37 immigrants arrived per house built, compared to 1.11 under Conservatives. While this suggests a slightly higher housing pressure under Liberal governments, the ratio doesn't account for broader housing demand or supply-side dynamics — including domestic needs, emigration, or housing delays.

# %% [markdown]
# ### Plotting

# %%
labels = ['Liberals', 'Conservative']
ticks = np.arange(len(labels))
imm_vals = [party_stats.loc['Liberals', 'imm_total'], party_stats.loc['Conservative', 'imm_total']]
houses = [party_stats.loc['Liberals', 'Housing completions'],party_stats.loc['Liberals', 'Housing completions']]
width = 0.35
fig,ax = plt.subplots(figsize=(10,6))
bar1 = ax.bar(ticks-width/2, imm_vals, width, label='immigration', color='lightgreen')
bar2 = ax.bar(ticks+width/2, houses, width, label='Houses built', color='lightgrey')

ax.set_ylabel('Average Count')
ax.set_title('Average Immigration vs Housing Completions by Party')
ax.set_xticks(ticks)
ax.set_xticklabels(labels)
ax.grid(axis='y', linestyle='--', alpha=0.5)

for bar_group in [bar1, bar2]:
    for bar in bar_group:
        y = bar.get_height()
        ax.text(bar.get_x()+width/2,y+2000, f'{y:.0f}', ha='center', va='bottom', fontsize=9)
        
plt.tight_layout()
plt.show()

# %%
crime = pd.read_csv('crime.csv', skiprows=1)
crime = crime.iloc[0:61]
crime = crime[['Unnamed: 0','Total']].astype(int)
crime = crime.set_index('Unnamed: 0')

# %%
df.index = df.index.astype(int)

# %%
df = df.join(crime['Total'])

# %%
df.rename(columns={'Total': 'Total_crime_per_1000'}, inplace=True)
df
# Out:
#      imm_total  Ruling_Party  Housing completions  Total_crime_per_1000
# 1980  143135.0      Liberals               176168                  8343
# 1981  128618.0      Liberals               174996                  8736
# 1982  121147.0      Liberals               133942                  8773
# 1983   89157.0      Liberals               163008                  8470
# 1984   88239.0  Conservative               153012                  8387
# 1985   84302.0  Conservative               139106                  8413
# 1986   99354.0  Conservative               184605                  8727
# 1987  152098.0  Conservative               217976                  8957
# 1988  161929.0  Conservative               216532                  8919
# 1989  192001.0  Conservative               217371                  8892
# 1990  214230.0  Conservative               206163                  9485
# 1991  232800.0  Conservative               160014                 10342
# ...

# %% [markdown]
# #### Data used from STATS CANADA

# %%
years = list(range(1980, 2023))
rates = [
    7.5, 7.6, 11.1, 12.0, 11.3, 10.6, 9.7, 8.8, 7.8, 7.5,
    8.1, 10.3, 11.2, 11.4, 10.4, 9.5, 9.7, 9.1, 8.3, 7.6,
    6.8, 7.2, 7.7, 7.6, 7.2, 6.8, 6.3, 6.2, 6.3, 8.3,
    7.9, 7.5, 7.3, 7.1, 6.9, 6.9, 7.0, 6.4, 5.8, 5.9,
    9.7, 7.5, 5.3
]
unemployment = pd.DataFrame({
    "Year": years,
    "Unemployment Rate (%)": rates
})

# %%
unemployment = unemployment.set_index('Year')

# %%
df = df.join(unemployment['Unemployment Rate (%)'])
df
# Out:
#      imm_total  Ruling_Party  Housing completions  Total_crime_per_1000  \
# 1980  143135.0      Liberals               176168                  8343
# 1981  128618.0      Liberals               174996                  8736
# 1982  121147.0      Liberals               133942                  8773
# 1983   89157.0      Liberals               163008                  8470
# 1984   88239.0  Conservative               153012                  8387
# 1985   84302.0  Conservative               139106                  8413
# 1986   99354.0  Conservative               184605                  8727
# 1987  152098.0  Conservative               217976                  8957
# 1988  161929.0  Conservative               216532                  8919
# 1989  192001.0  Conservative               217371                  8892
# 1990  214230.0  Conservative               206163                  9485
# 1991  232800.0  Conservative               160014                 10342
# ...

# %%
numeric_df = df.select_dtypes(include='number')

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='YlGnBu', fmt=".2f")
plt.title("Correlation Between Immigration, Crime, Unemployment, and Housing")
plt.show()

# %% [markdown]
# ## Descriptive Statistics
# We begin with basic descriptive statistics to understand the scale, spread, and central tendencies in immigration and housing data.

# %%
df[['imm_total', 'Housing completions']].describe()
# Out:
#        Housing completions
# count            43.000000
# mean         179811.976744
# std           29257.889007
# min          117834.000000
# 25%          160904.000000
# 50%          184605.000000
# 75%          203212.500000
# max          222670.000000

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df['imm_total'], kde=True, color='skyblue')
plt.title('Distribution of Immigration')

plt.subplot(1, 2, 2)
sns.histplot(df['Housing completions'], kde=True, color='salmon')
plt.title('Distribution of Housing Completions')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Trends Over Time
# Let's explore how immigration and housing completions evolve over time using percentage changes and rolling averages.

# %%
df['imm_pct_change'] = df['imm_total'].pct_change() * 100
df['house_pct_change'] = df['Housing completions'].pct_change() * 100

plt.figure(figsize=(14, 6))
plt.plot(df.index, df['imm_pct_change'], label='Immigration % Change', color='green')
plt.plot(df.index, df['house_pct_change'], label='Housing % Change', color='orange')
plt.axhline(0, color='black', linestyle='--')
plt.title('Year-over-Year % Change')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\06san\AppData\Local\Temp\ipykernel_50384\1897332321.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['imm_pct_change'] = df['imm_total'].pct_change() * 100

# %%
df['imm_rolling'] = df['imm_total'].rolling(window=3).mean()
df['house_rolling'] = df['Housing completions'].rolling(window=3).mean()

plt.figure(figsize=(14, 6))
plt.plot(df.index, df['imm_total'], label='Immigration', alpha=0.5)
plt.plot(df.index, df['house_rolling'], label='3-year Rolling Housing', color='blue', linewidth=2)
plt.plot(df.index, df['imm_rolling'], label='3-year Rolling Immigration', color='red', linewidth=2)
plt.legend()
plt.title('Immigration and Housing with 3-Year Rolling Average')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Between Variables
# We check for linear relationships between immigration and housing completions using a heatmap.

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df[['imm_total', 'Housing completions']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Between Immigration and Housing')
plt.show()

# %% [markdown]
# ## Annotating Political Periods
# Vertical dashed lines mark changes in ruling political parties, helping us spot how transitions may impact trends.

# %%
df['party_shift'] = df['Ruling_Party'] != df['Ruling_Party'].shift(1)
change_years = df[df['party_shift']].index

plt.figure(figsize=(14, 6))
plt.plot(df.index, df['imm_total'], label='Immigration')

for year in change_years:
    plt.axvline(x=year, color='gray', linestyle='--', alpha=0.7)

plt.legend()
plt.title('Immigration Over Time with Party Changes Marked')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Descriptive Statistics
# We begin with basic descriptive statistics to understand the scale, spread, and central tendencies in immigration and housing data.

# %%
df[['imm_total', 'Housing completions']].describe()
# Out:
#        Housing completions
# count            43.000000
# mean         179811.976744
# std           29257.889007
# min          117834.000000
# 25%          160904.000000
# 50%          184605.000000
# 75%          203212.500000
# max          222670.000000

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df['imm_total'], kde=True, color='skyblue')
plt.title('Distribution of Immigration')

plt.subplot(1, 2, 2)
sns.histplot(df['Housing completions'], kde=True, color='salmon')
plt.title('Distribution of Housing Completions')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Trends Over Time
# Let's explore how immigration and housing completions evolve over time using percentage changes and rolling averages.

# %%
df['imm_pct_change'] = df['imm_total'].pct_change() * 100
df['house_pct_change'] = df['Housing completions'].pct_change() * 100

plt.figure(figsize=(14, 6))
plt.plot(df.index, df['imm_pct_change'], label='Immigration % Change', color='green')
plt.plot(df.index, df['house_pct_change'], label='Housing % Change', color='orange')
plt.axhline(0, color='black', linestyle='--')
plt.title('Year-over-Year % Change')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\06san\AppData\Local\Temp\ipykernel_50384\1897332321.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['imm_pct_change'] = df['imm_total'].pct_change() * 100

# %%
df['imm_rolling'] = df['imm_total'].rolling(window=3).mean()
df['house_rolling'] = df['Housing completions'].rolling(window=3).mean()

plt.figure(figsize=(14, 6))
plt.plot(df.index, df['imm_total'], label='Immigration', alpha=0.5)
plt.plot(df.index, df['house_rolling'], label='3-year Rolling Housing', color='blue', linewidth=2)
plt.plot(df.index, df['imm_rolling'], label='3-year Rolling Immigration', color='red', linewidth=2)
plt.legend()
plt.title('Immigration and Housing with 3-Year Rolling Average')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Between Variables
# We check for linear relationships between immigration and housing completions using a heatmap.

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df[['imm_total', 'Housing completions']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Between Immigration and Housing')
plt.show()

# %% [markdown]
# ## Annotating Political Periods
# Vertical dashed lines mark changes in ruling political parties, helping us spot how transitions may impact trends.

# %%
df['party_shift'] = df['Ruling_Party'] != df['Ruling_Party'].shift(1)
change_years = df[df['party_shift']].index

plt.figure(figsize=(14, 6))
plt.plot(df.index, df['imm_total'], label='Immigration')

for year in change_years:
    plt.axvline(x=year, color='gray', linestyle='--', alpha=0.7)

plt.legend()
plt.title('Immigration Over Time with Party Changes Marked')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
